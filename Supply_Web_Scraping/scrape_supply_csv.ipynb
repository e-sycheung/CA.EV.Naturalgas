# %%
# Import the dependencies
import os
import requests
import pandas as pd

# %%
# 3/16/2022 supply data CSV from CAISO Network XHR
url = 'https://www.caiso.com/outlook/SP/History/20220316/fuelsource.csv?_=1647651289493'

# %%
# Save CSV to local machine
proxies = {}
response = requests.get(url=url, proxies=proxies)
with open('supply_2022_03_16.csv', 'wb') as f:
    f.write(response.content)

# %%
# Save CSV to DataFrame
supply_2022_03_16_df = pd.read_csv(url)
supply_2022_03_16_df
# Out:
#       Time  Solar  Wind  Geothermal  Biomass  Biogas  Small hydro  Coal  \
# 0    00:00    -43  4894         900      281     194          161    10
# 1    00:05    -43  5024         900      279     194          160    11
# 2    00:10    -43  5076         899      285     194          151    11
# 3    00:15    -42  5098         900      285     194          140    10
# 4    00:20    -42  5070         899      284     194          141    11
# ..     ...    ...   ...         ...      ...     ...          ...   ...
# 283  23:35    -42  3911         904      306     199          151     9
# 284  23:40    -41  3868         903      306     199          152     9
# 285  23:45    -41  3820         903      308     199          151     9
# 286  23:50    -41  3806         903      306     199          150     9
# 287  23:55    -41  3726         903      309     199          149     9
#
#      Nuclear  Natural Gas  Large Hydro  Batteries  Imports  Other
# 0       2127         5353         1087        -88     7819      0
# 1       2127         5197         1004         -3     7857      0
# 2       2127         5060          869         -8     8022      0
# 3       2126         5024          872        -18     8017      0
# 4       2128         4928          873         21     8051      0
# ..       ...          ...          ...        ...      ...    ...
# 283     2115         5915         1292         88     8128      0
# 284     2114         5842         1277         59     8156      0
# 285     2115         5848         1277         53     8168      0
# 286     2115         5726         1247         -5     8255      0
# 287     2115         5724         1228        103     8238      0
#
# [288 rows x 14 columns]
