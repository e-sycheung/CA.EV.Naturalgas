# %%
pip install hvplot
# Out:
# Requirement already satisfied: hvplot in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (0.7.3)
# Requirement already satisfied: pandas in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from hvplot) (1.4.1)
# Requirement already satisfied: holoviews>=1.11.0 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from hvplot) (1.14.8)
# Requirement already satisfied: colorcet>=2 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from hvplot) (3.0.0)
# Requirement already satisfied: bokeh>=1.0.0 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from hvplot) (2.4.2)
# Requirement already satisfied: numpy>=1.15 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from hvplot) (1.22.2)
# Requirement already satisfied: pillow>=7.1.0 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from bokeh>=1.0.0->hvplot) (9.0.1)
# Requirement already satisfied: tornado>=5.1 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from bokeh>=1.0.0->hvplot) (6.1)
# Requirement already satisfied: packaging>=16.8 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from bokeh>=1.0.0->hvplot) (21.3)
# Requirement already satisfied: typing-extensions>=3.10.0 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from bokeh>=1.0.0->hvplot) (4.1.1)
# Requirement already satisfied: PyYAML>=3.10 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from bokeh>=1.0.0->hvplot) (6.0)
# Requirement already satisfied: Jinja2>=2.9 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from bokeh>=1.0.0->hvplot) (3.0.3)
# Requirement already satisfied: param>=1.7.0 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from colorcet>=2->hvplot) (1.12.0)
# Requirement already satisfied: pyct>=0.4.4 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from colorcet>=2->hvplot) (0.4.8)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from holoviews>=1.11.0->hvplot) (2.1.0)
# Requirement already satisfied: panel>=0.8.0 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from holoviews>=1.11.0->hvplot) (0.12.6)
# Requirement already satisfied: pytz>=2020.1 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from pandas->hvplot) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from pandas->hvplot) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from packaging>=16.8->bokeh>=1.0.0->hvplot) (3.0.7)
# Requirement already satisfied: markdown in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.3.6)
# Requirement already satisfied: tqdm>=4.48.0 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (4.63.0)
# Requirement already satisfied: requests in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (2.27.1)
# Requirement already satisfied: bleach in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (4.1.0)
# Requirement already satisfied: six>=1.5 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->hvplot) (1.16.0)
# Requirement already satisfied: webencodings in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from bleach->panel>=0.8.0->holoviews>=1.11.0->hvplot) (0.5.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (5.6.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /Users/rosestrauss/opt/anaconda3/envs/mlenv/lib/python3.10/site-packages (from plotly) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Initial imports
import pandas as pd
import hvplot.pandas
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

#  Import and read the file.
import pandas as pd 
weather_df = pd.read_csv("./minute_weather.csv")
weather_df.head()
# Out:
#    rowID hpwren_timestamp  air_pressure  air_temp  avg_wind_direction  \
# 0      0   9/10/2011 0:00         912.3     64.76                97.0
# 1      1   9/10/2011 0:01         912.3     63.86               161.0
# 2      2   9/10/2011 0:02         912.3     64.22                77.0
# 3      3   9/10/2011 0:03         912.3     64.40                89.0
# 4      4   9/10/2011 0:04         912.3     64.40               185.0
#
#    avg_wind_speed  max_wind_direction  max_wind_speed  min_wind_direction  \
# 0             1.2               106.0             1.7                85.0
# 1             0.8               215.0             1.5                43.0
# 2             0.7               143.0             1.2               324.0
# 3             1.2               112.0             1.6                12.0
# 4             0.4               260.0             1.0               100.0
#
#    min_wind_speed  rain_accumulation  rain_duration  relative_humidity
# 0             1.0                NaN            NaN               60.5
# 1             0.2                0.0            0.0               39.9
# 2             0.3                0.0            0.0               43.0
# 3             0.7                0.0            0.0               49.5
# 4             0.1                0.0            0.0               58.8

# %%
weather_df= weather_df.drop(['rowID', 'air_pressure', 'avg_wind_speed', 'max_wind_direction', 'max_wind_speed',	'min_wind_direction','min_wind_speed', 'rain_accumulation', 'rain_duration', 'relative_humidity', 'avg_wind_direction'],1)
weather_df.head()
# Out:
# /var/folders/td/gr2xrxfn4zj1kczpq_4hrmyr0000gn/T/ipykernel_87741/1695329182.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   weather_df= weather_df.drop(['rowID', 'air_pressure', 'avg_wind_speed', 'max_wind_direction', 'max_wind_speed',	'min_wind_direction','min_wind_speed', 'rain_accumulation', 'rain_duration', 'relative_humidity', 'avg_wind_direction'],1)
#   hpwren_timestamp  air_temp
# 0   9/10/2011 0:00     64.76
# 1   9/10/2011 0:01     63.86
# 2   9/10/2011 0:02     64.22
# 3   9/10/2011 0:03     64.40
# 4   9/10/2011 0:04     64.40

# %%
weather_df['hpwren_timestamp'] = pd.to_datetime(weather_df['hpwren_timestamp'])

# %%
weather_df.rename(columns = {'hpwren_timestamp':'date/time'}, inplace = True)
weather_df.head()
# Out:
#             date/time  air_temp
# 0 2011-09-10 00:00:00     64.76
# 1 2011-09-10 00:01:00     63.86
# 2 2011-09-10 00:02:00     64.22
# 3 2011-09-10 00:03:00     64.40
# 4 2011-09-10 00:04:00     64.40

# %%
# Use get_dummies() to create variables for text features.
X = pd.get_dummies(weather_df, columns=["date/time", "air_temp"])
print(X.shape)
X.head()
