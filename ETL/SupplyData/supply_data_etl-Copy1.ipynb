# %%
# Import dependencies
import pandas as pd
import os
import glob
import numpy as np
import datetime

# %%
# Use glob to get all the supply data csv files in the current working directory
path = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))

# %%
# Create empty list
dataframes_list = []

# %%
# Append datasets to the list 
for i in csv_files:
    temp_df = pd.read_csv(i)
    dataframes_list.append(temp_df)

# %%
# Check dataframes_list length for all suppy data CSV files
len(dataframes_list)
# Out:
# 1446

# %%
# Create empty list for transformed DataFrames
transformed_dfs = []

# %%
# Transform each DataFrame in dataframes_list and append to transformed_dfs
for df in dataframes_list:    
    # Create date variable
    date = df.columns[0]

    # Reset index to energy sources and transpose
    df_transposed = df.set_index(date).T
    
    # Create date column
    df_transposed["Date"] = date
    
    # Create time column 
    df_transposed["Time"] = df_transposed.index
    
    # Create hours column
    df_transposed["Hours"] = pd.Series()
    for t in df_transposed["Time"]:
        hours_mins = t.split(":")
        hours = hours_mins[0]
        df_transposed["Hours"].append(hours)
        print(df_transposed["Hours"])

    # Reset index to start from 0
    df_transposed.reset_index(drop=True, inplace=True)
    
    transformed_dfs.append(df_transposed)
# Out:
# Renewables
# 2005.0    object
# 2005.0    object
# 2048.0    object
# 1979.0    object
# 1980.0    object
#            ...
# 3363.0    object
# 3316.0    object
# 3299.0    object
# Date      object
# Time      object
# Length: 412958, dtype: object
# 4/10/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/11/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/12/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/13/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/14/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/15/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/16/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/17/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/18/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/19/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/20/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/21/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/22/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/23/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/24/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/25/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/26/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/27/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/28/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/29/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 4/30/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/1/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/2/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/3/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/4/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/5/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/6/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/7/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/8/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/9/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/10/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/11/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/12/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/13/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/14/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/15/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/16/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/17/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/18/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/19/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/20/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/21/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/22/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/23/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/24/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/25/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/26/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/27/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/28/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/29/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/30/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 5/31/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/1/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/2/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/3/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/4/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/5/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/6/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/7/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/8/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/9/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/10/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/11/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/12/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/13/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/14/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/15/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/16/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/17/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/18/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/19/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/20/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/21/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/22/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/23/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/24/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/25/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/26/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/27/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/28/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/29/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 6/30/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/1/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/2/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/3/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/4/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/5/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/6/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/7/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/8/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/9/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/10/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/11/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/12/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/13/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/14/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/15/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/16/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/17/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/18/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/19/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/20/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/21/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/22/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/23/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/24/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/25/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/26/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/27/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/28/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/29/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/30/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 7/31/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/1/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/2/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/3/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/4/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/5/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/6/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/7/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/8/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/9/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/10/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/11/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/12/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/13/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/14/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/15/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/16/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/17/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/18/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/19/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/20/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/21/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/22/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/23/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/24/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/25/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/26/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/27/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/28/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/29/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/30/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 8/31/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/1/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/2/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/3/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/4/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/5/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/6/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/7/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/8/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/9/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/10/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/11/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/12/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/13/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/14/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/15/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/16/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/17/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/18/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/19/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/20/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/21/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/22/2018
# Renewables     float64
# Natural gas    float64
# Large hydro    float64
# Imports        float64
# Batteries      float64
# Nuclear        float64
# Coal           float64
# Other          float64
# Date            object
# Time            object
# dtype: object
# 9/23/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/24/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/25/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/26/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/27/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/28/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/29/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 9/30/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/1/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/2/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/3/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/4/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/5/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/6/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/7/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/8/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/9/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/10/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/11/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/12/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/13/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/14/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/15/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/16/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/17/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/18/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/19/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/20/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/21/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 10/22/2018
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# ...
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 1/19/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 1/20/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 1/21/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 1/22/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 1/23/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 1/24/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 1/25/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 1/26/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 1/27/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 1/28/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 1/29/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 1/30/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 1/31/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/1/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/2/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/3/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/4/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/5/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/6/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/7/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/8/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/9/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/10/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/11/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/12/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/13/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/14/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/15/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/16/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/17/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/18/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/19/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/20/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/21/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/22/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/23/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/24/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/25/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/26/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/27/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 2/28/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/1/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/2/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/3/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/4/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/5/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/6/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/7/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/8/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/9/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/10/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/11/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/12/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/13/2022
# Renewables     float64
# Natural gas    float64
# Large hydro    float64
# Imports        float64
# Batteries      float64
# Nuclear        float64
# Coal           float64
# Other          float64
# Date            object
# Time            object
# dtype: object
# 3/14/2022
# Renewables     float64
# Natural gas    float64
# Large hydro    float64
# Imports        float64
# Batteries      float64
# Nuclear        float64
# Coal           float64
# Other          float64
# Date            object
# Time            object
# dtype: object
# 3/15/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/16/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/17/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/18/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/19/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/20/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/21/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/22/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/23/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object
# 3/24/2022
# Renewables      int64
# Natural gas     int64
# Large hydro     int64
# Imports         int64
# Batteries       int64
# Nuclear         int64
# Coal            int64
# Other           int64
# Date           object
# Time           object
# dtype: object

# %%
# Create empty DataFrame for all supply data
supply_df = pd.DataFrame()

# %%
# Append each DataFrame in transformed_dfs to supply_df
for df in transformed_dfs:
    supply_df = supply_df.append(df, ignore_index = True)

supply_df.info()
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15656/4019754910.py in <module>
#       1 # Append each DataFrame in transformed_dfs to supply_df
#       2 for df in transformed_dfs:
# ----> 3     supply_df = supply_df.append(df, ignore_index = True)
#       4
#       5 supply_df.info()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    8967                 ignore_index=ignore_index,
#    8968                 verify_integrity=verify_integrity,
# -> 8969                 sort=sort,
#    8970             )
#    8971         ).__finalize__(self, method="append")
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     305     )
#     306
# --> 307     return op.get_result()
#     308
#     309
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     526                     obj_labels = obj.axes[1 - ax]
#     527                     if not new_labels.equals(obj_labels):
# --> 528                         indexers[ax] = obj_labels.get_indexer(new_labels)
#     529
#     530                 mgrs_indexers.append((obj._mgr, indexers))
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    3440
#    3441         if not self._index_as_unique:
# -> 3442             raise InvalidIndexError(self._requires_unique_msg)
#    3443
#    3444         if not self._should_compare(target) and not is_interval_dtype(self.dtype):
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
# Check supply_df for null values
supply_df.isnull().sum()

# %%
# Create the output file (CSV)
output_data_file = "CAISO-ALL-SUPPLY-DATA.csv"

# Export the DataFrame into a CSV without the index
supply_df.to_csv(output_data_file, index=False)
